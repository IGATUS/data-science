# %%
import pandas as pd
import numpy as np
tri = pd.read_excel('budget.xlsx')
tri
# Out:
#     Unnamed: 0                              BUDGET Unnamed: 2  \
# 0          NaN                                 NaN        NaN
# 1          NaN                         Description        Qty
# 2          NaN            Personnel Cost/Allowance        NaN
# 3          NaN                 Computer Programmer          1
# 4          NaN                   Software Designer          1
# 5          NaN    Technical/Administrative Support          2
# 6          NaN                             Tailors         30
# 7          NaN                                 NaN        NaN
# 8          NaN                                 NaN        NaN
# 9          NaN       Equipment/Supplies/Consumable        NaN
# 10         NaN           Solar powered school bags        NaN
# 11         NaN                      Sewing machine         30
# 12         NaN             Fabric material (yards)      10000
# 13         NaN                Bag handles (pieces)      10000
# ...
