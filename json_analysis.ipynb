# %%
import pandas as pd
import numpy as np
content = pd.read_csv('annual.csv')

# %%
content
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
content.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
single = content[content.Year==2013]
single
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 27810  2013                     Level 1                99999
# 27811  2013                     Level 1                99999
# 27812  2013                     Level 1                99999
# 27813  2013                     Level 1                99999
# 27814  2013                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 27810              All industries  Dollars (millions)           H01
# 27811              All industries  Dollars (millions)           H04
# ...

# %%
double= content[content.Variable_code=='H01']
double
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 31     2019                     Level 1                   AA
# 62     2019                     Level 3                 AA11
# 92     2019                     Level 4                AA111
# 122    2019                     Level 3                 AA12
# ...     ...                         ...                  ...
# 32281  2013                     Level 3                 RS21
# 32313  2013                     Level 4                RS211
# 32345  2013                     Level 4                RS212
# 32377  2013                     Level 4                RS214
# 32409  2013                     Level 3                 ZZ11
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# ...

# %%
lockdown=content.loc[2:7,['Year','Value']]
lockdown
# Out:
#    Year    Value
# 2  2019   62,924
# 3  2019   21,505
# 4  2019  634,710
# 5  2019   35,250
# 6  2019    7,458
# 7  2019   20,977

# %%
content.iloc[2:7,8]
# Out:
# 2     62,924
# 3     21,505
# 4    634,710
# 5     35,250
# 6      7,458
# Name: Value, dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
content.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2019                     Level 1                99999       All industries
# 1  2019                     Level 1                99999       All industries
# 2  2019                     Level 1                99999       All industries
# 3  2019                     Level 1                99999       All industries
# 4  2019                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 2  Dollars (millions)           H05
# 3  Dollars (millions)           H07
# 4  Dollars (millions)           H08
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
lockdown.head()
# Out:
#    Year    Value
# 2  2019   62,924
# 3  2019   21,505
# 4  2019  634,710
# 5  2019   35,250
# 6  2019    7,458

# %%
plt.plot(lockdown.Year,lockdown.Value)
plt.xlabel('Year')
plt.ylabel('Value')
plt.show()

# %% [markdown]
# # working with json

# %%
book={}
book['tom']={
    'name':'tom',
    'address':'anyigba state',
    'phone':23243432
}
book['igatus']={
    'name':'igatus',
    'address':'kogi state',
    'phone':23243532
}
import json
s=json.dumps(book) # the s in dumps stands for string, thus it mean dump as a string
s
# Out:
# '{"tom": {"name": "tom", "address": "anyigba state", "phone": 23243432}, "igatus": {"name": "igatus", "address": "kogi state", "phone": 23243532}}'

# %%
with open('book.txt','w') as f:
    f.write(s)

# %%
book=json.loads(s)
book
# Out:
# {'tom': {'name': 'tom', 'address': 'anyigba state', 'phone': 23243432},
#  'igatus': {'name': 'igatus', 'address': 'kogi state', 'phone': 23243532}}

# %%
type(book)
# Out:
# dict

# %%
book['tom']
# Out:
# {'name': 'tom', 'address': 'anyigba state', 'phone': 23243432}

# %%
for i in book:
    print(book[i])
# Out:
# {'name': 'tom', 'address': 'anyigba state', 'phone': 23243432}
# {'name': 'igatus', 'address': 'kogi state', 'phone': 23243532}
