# %%
import pandas as pd
import numpy as np
data={'states':['kogi','benue','niger','lagos','abuja'],
     'year':[2000,2001,2002,2003,2004],
     'pop':[1.2,2.3,2.5,9.0,4.5]}
frame=pd.DataFrame(data)
frame

# %%
frame2=pd.DataFrame(data,columns=['pop','year','states'])
frame2
# Out:
#    pop  year states
# 0  1.2  2000   kogi
# 1  2.3  2001  benue
# 2  2.5  2002  niger
# 3  9.0  2003  lagos
# 4  4.5  2004  abuja

# %%
frame3=pd.DataFrame(data,columns=['year','pop','states','depts'],index=['one','two','three','four','five'])
frame3['depts']=12.4
frame3['depts']=np.arange(5.)
frame3
# Out:
#        year  pop states  depts
# one    2000  1.2   kogi    0.0
# two    2001  2.3  benue    1.0
# three  2002  2.5  niger    2.0
# four   2003  9.0  lagos    3.0
# five   2004  4.5  abuja    4.0

# %%
frame3.year
# Out:
# one      2000
# two      2001
# three    2002
# four     2003
# five     2004
# Name: year, dtype: int64

# %%
frame3['states']
# Out:
# one       kogi
# two      benue
# three    niger
# four     lagos
# five     abuja
# Name: states, dtype: object

# %%
sict={'scores':{'maths':100,'english':50,'physics':80,'chemistry':78},
     'results':{'ABE':50,'MCE':60,'TELECOM':70,'ELECT':68}}
obj3=pd.DataFrame(sict)
obj3
# Out:
#            scores  results
# maths       100.0      NaN
# english      50.0      NaN
# physics      80.0      NaN
# chemistry    78.0      NaN
# ABE           NaN     50.0
# MCE           NaN     60.0
# TELECOM       NaN     70.0
# ELECT         NaN     68.0

# %%
obj3.T
# Out:
#          maths  english  physics  chemistry   ABE   MCE  TELECOM  ELECT
# scores   100.0     50.0     80.0       78.0   NaN   NaN      NaN    NaN
# results    NaN      NaN      NaN        NaN  50.0  60.0     70.0   68.0

# %%
obj2=pd.DataFrame(sict,index=[1,2,3,4,5,6])
obj2
# Out:
#    scores  results
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN
# 5     NaN      NaN
# 6     NaN      NaN

# %%
frame4=pd.Series(['storm','may','come'],index=[0,2,4])
frame4
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7e0ce0f43bb0> in <module>
# ----> 1 frame4=pd.Series(['storm','may','come'],index=[0,2,4])
#       2 frame4
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_excel('paul.xlsx')
df
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
# 5    8   KELVIN     59       66      87       51    49     312     62.4
# 6    3  STEPHEN     28       81      61       64    59     293     58.6
# 7    4    DAVID     61       26      51       45    95     278     55.6
#
#   POSITION
# 0      1ST
# 1      2ND
# 2      3RD
# 3      4TH
# 4      5TH
# 5      6TH
# 6      7TH
# 7      8TH

# %%
df.head()
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
#
#   POSITION
# 0      1ST
# 1      2ND
# 2      3RD
# 3      4TH
# 4      5TH

# %%
df.plot()

# %%
df['MATHS'].plot()

# %%
df.plot.scatter(x='NAME',y='MATHS')

# %%
[i for i in dir(df.plot) if not i.startswith('_')]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
df.plot.bar(x='NAME',y='MATHS')

# %%
df.plot.box()

# %%
df.plot.area(figsize=(24,16),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000000009E58E20>,
# ...
#       dtype=object)

# %%
fig,axs=plt.subplots(figsize=(24,16))

# %%
df.plot.area(ax=axs)

# %%
axs.set_ylabel("NO$_2$ concentration")
# Out:
# Text(3.200000000000017, 0.5, 'NO$_2$ concentration')

# %%
frame2=pd.read_excel('paul.xlsx')
frame2
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
# 5    8   KELVIN     59       66      87       51    49     312     62.4
# 6    3  STEPHEN     28       81      61       64    59     293     58.6
# 7    4    DAVID     61       26      51       45    95     278     55.6
#
#   POSITION
# 0      1ST
# 1      2ND
# 2      3RD
# 3      4TH
# 4      5TH
# 5      6TH
# 6      7TH
# 7      8TH

# %%
frame2['hydraulic']=frame2['MATHS']*2
frame2.head()
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
#
#   POSITION  hydraulic
# 0      1ST        138
# 1      2ND        188
# 2      3RD        182
# 3      4TH        112
# 4      5TH        130

# %%
frame2['ratio']=frame2['MATHS']/frame2['ENGLISH']

# %%
frame2.head()
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
#
#   POSITION  hydraulic     ratio
# 0      1ST        138  1.169492
# 1      2ND        188  1.000000
# 2      3RD        182  2.459459
# 3      4TH        112  1.750000
# 4      5TH        130  1.160714

# %%
frame2_renamed=frame2.rename(columns={'MATHS':'mathematics','ENGLISH':'french','SOCIAL':'GST'})
frame2_renamed.head()
# Out:
#    S/N     NAME  mathematics  french  GST  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER           69      59   99       92   100     419     83.8
# 1    7   KIZITO           94      94   94       51    59     392     78.4
# 2    5   DORCAS           91      37   95       61    49     333     66.6
# 3    6  FELICIA           56      32   96       48    94     326     65.2
# 4    2     JOHN           65      56   56       51    95     323     64.6
#
#   POSITION  hydraulic     ratio
# 0      1ST        138  1.169492
# 1      2ND        188  1.000000
# 2      3RD        182  2.459459
# 3      4TH        112  1.750000
# 4      5TH        130  1.160714

# %%
frame2.describe()
# Out:
#            S/N      MATHS    ENGLISH    SOCIAL    F/MATHS        LIT   \
# count  8.00000   8.000000   8.000000   8.00000   8.000000    8.000000
# mean   4.50000  65.375000  56.375000  79.87500  57.875000   75.000000
# std    2.44949  20.818519  23.945996  20.23037  15.198097   22.834811
# min    1.00000  28.000000  26.000000  51.00000  45.000000   49.000000
# 25%    2.75000  58.250000  35.750000  59.75000  50.250000   56.500000
# 50%    4.50000  63.000000  57.500000  90.50000  51.000000   76.500000
# 75%    6.25000  74.500000  69.750000  95.25000  61.750000   95.000000
# max    8.00000  94.000000  94.000000  99.00000  92.000000  100.000000
#
#            TOTAAL    AVERAGE   hydraulic     ratio
# count    8.000000   8.000000    8.000000  8.000000
# mean   334.500000  66.900000  130.750000  1.390680
# std     47.919575   9.583915   41.637037  0.734609
# min    278.000000  55.600000   56.000000  0.345679
# 25%    307.250000  61.450000  116.500000  0.973485
# ...

# %%
frame2.agg({'MATHS':['mean','median'],
           'ENGLISH':['mean','median']})
# Out:
#          MATHS  ENGLISH
# mean    65.375   56.375
# median  63.000   57.500

# %%
import pandas as pd
frame3=pd.read_excel('paul.xlsx')
frame3
# Out:
#    S/N     NAME  MATHS  ENGLISH  SOCIAL  F/MATHS  LIT   TOTAAL  AVERAGE  \
# 0    1    PETER     69       59      99       92   100     419     83.8
# 1    7   KIZITO     94       94      94       51    59     392     78.4
# 2    5   DORCAS     91       37      95       61    49     333     66.6
# 3    6  FELICIA     56       32      96       48    94     326     65.2
# 4    2     JOHN     65       56      56       51    95     323     64.6
# 5    8   KELVIN     59       66      87       51    49     312     62.4
# 6    3  STEPHEN     28       81      61       64    59     293     58.6
# 7    4    DAVID     61       26      51       45    95     278     55.6
#
#   POSITION
# 0      1ST
# 1      2ND
# 2      3RD
# 3      4TH
# 4      5TH
# 5      6TH
# 6      7TH
# 7      8TH

# %%
df=frame3.set_index('S/N',inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-479064237953> in <module>
# ----> 1 df=frame3.set_index('S/N',inplace=True)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['S/N'] are in the columns"

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('annull.csv')
df
# Out:
#        year industry_code_ANZSIC               industry_name_ANZSIC  \
# 0      2011                    A  Agriculture, Forestry and Fishing
# 1      2011                    A  Agriculture, Forestry and Fishing
# 2      2011                    A  Agriculture, Forestry and Fishing
# 3      2011                    A  Agriculture, Forestry and Fishing
# 4      2011                    A  Agriculture, Forestry and Fishing
# ...     ...                  ...                                ...
# 13927  2019                  all                     All Industries
# 13928  2019                  all                     All Industries
# 13929  2019                  all                     All Industries
# 13930  2019                  all                     All Industries
# 13931  2019                  all                     All Industries
#
#         rme_size_grp                                         variable  \
# 0                a_0                                    Activity unit
# ...

# %%
df.shape
# Out:
# (13932, 7)

# %%
len(df)
# Out:
# 13932

# %% [markdown]
# # importing the business csv file

# %%
ff=pd.read_csv('annual.csv')
ff
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2019                     Level 1                99999
# 1      2019                     Level 1                99999
# 2      2019                     Level 1                99999
# 3      2019                     Level 1                99999
# 4      2019                     Level 1                99999
# ...     ...                         ...                  ...
# 32440  2013                     Level 3                 ZZ11
# 32441  2013                     Level 3                 ZZ11
# 32442  2013                     Level 3                 ZZ11
# 32443  2013                     Level 3                 ZZ11
# 32444  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
import pandas as pd
from chembl_webresource.new_client import new_client

# %% [markdown]
# # search for the target protein

# %% [markdown]
# # Target search for coronavirus
